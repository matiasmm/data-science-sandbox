# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import random
from working_with_data import *
from linear_algebra import *

# %%
# Generating data
data = [[x + random.randint(0, 10), x + random.randint(0, 10)] for x in range(300)]

# %%
plt.plot(get_column(data, 0), get_column(data, 1), "ko", markersize=2)
plt.show()

# %%
datac = de_mean_matrix(data)
plt.plot(get_column(datac, 0), get_column(datac, 1), "ko", markersize=2)
plt.show()

# %%
first_principal_component(datac)
# Out:
# [0.7070048762396682, 0.707208671449475]
